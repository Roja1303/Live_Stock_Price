# %%
from SharekhanApi.sharekhanConnect import SharekhanConnect
# from sharekhan.webSocket  import webSocket
from SharekhanApi.sharekhanWebsocket import SharekhanWebSocket

import json
import requests

# %%
api_key = "y6AyRoJDINqkdKhpLyBYLcvGhnyqu0PK"
login = SharekhanConnect(api_key)
vendor_key = ""         # vendor key for vendor login otherwise keep it null
version_id = "1005"         # version id= 1005 or 1006 otherwise keep it null
state=12345
url = login.login_url(vendor_key, version_id)
print(url)
# Out:
# No Vendor Key
# https://api.sharekhan.com/skapi/auth/login.html?api_key=y6AyRoJDINqkdKhpLyBYLcvGhnyqu0PK&state=12345&version_id=1005

# %%
request_token = "NyjPfHGufF_Iu5EeiLKNMvPVDdFvuP8c8wQso1el0LlKA-cIpucdtsvpsDaxw-TEUtFWX70r5Rw=&state=12345"
secret_key = "vq6kcId2bY6ChKRlZXDwvMSMvRCwAvgl"

session = login.generate_session(request_token,secret_key)
access_token = login.get_access_token(api_key,session,state,versionId=version_id)

print(access_token)
# Out:
# {'status': 200, 'message': 'access_token', 'timestamp': '2025-02-24T14:52:49+05:30', 'data': {'customerId': '3975103', 'loginId': '3975103', 'btplusServiceEnabled': False, 'userId': None, 'token': 'eyJ0eXAiOiJzZWMiLCJhbGciOiJIUzI1NiJ9..KUjRlHJrtJ7xK0HJ8BTWf5JEyjww1dRhH4aZ55TtDEM', 'exchanges': ['BC', 'NC'], 'broker': 'Sharekhan', 'fullName': 'ROJA   SHANKAR', 'state': '12345'}}

# %%
access_token = "eyJ0eXAiOiJzZWMiLCJhbGciOiJIUzI1NiJ9..KUjRlHJrtJ7xK0HJ8BTWf5JEyjww1dRhH4aZ55TtDEM"
sharekhan = SharekhanConnect(api_key=api_key,access_token=access_token)
print("Access_token:",access_token)

print(sharekhan.requestHeaders())
# Out:
# Access_token: eyJ0eXAiOiJzZWMiLCJhbGciOiJIUzI1NiJ9..KUjRlHJrtJ7xK0HJ8BTWf5JEyjww1dRhH4aZ55TtDEM
# {'api-key': 'y6AyRoJDINqkdKhpLyBYLcvGhnyqu0PK', 'access-token': 'eyJ0eXAiOiJzZWMiLCJhbGciOiJIUzI1NiJ9..KUjRlHJrtJ7xK0HJ8BTWf5JEyjww1dRhH4aZ55TtDEM', 'Content-type': 'application/json'}

# %% [markdown]
# ScripMaster

# %%
access_token = "eyJ0eXAiOiJzZWMiLCJhbGciOiJIUzI1NiJ9..KUjRlHJrtJ7xK0HJ8BTWf5JEyjww1dRhH4aZ55TtDEM"
api_key = "y6AyRoJDINqkdKhpLyBYLcvGhnyqu0PK"

# Exchange Codes Mapping
EXCHANGE = {
    "NC": "NSE",
    "BC": "BSE",
    "NF": "NSE F&O",
    "MX": "MCX Commodities",
    "RN": "Currency Derivatives"
}

# API Base URL
BASE_URL = "https://api.sharekhan.com/skapi/services/master"

def fetch_scrips_by_exchange(exchange_code, search_scrip=None):
    """Fetch active scrips for a specific exchange and filter by scrip name (if provided)."""

    exchange_name = EXCHANGE.get(exchange_code.upper())  # Convert to uppercase & get full name
    if not exchange_name:
        print(f"❌ Invalid exchange code '{exchange_code}'. Choose from: {list(EXCHANGE.keys())}")
        return

    url = f"{BASE_URL}/{exchange_code.upper()}"
    headers = {
        "Authorization": f"Bearer {access_token}",
        "api-key": api_key,
        "Content-Type": "application/json"
    }

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        data = response.json().get("data", [])

        # Filter based on the given scrip name (if provided)
        if search_scrip:
            filtered_data = [scrip for scrip in data if scrip['tradingSymbol'].upper().startswith(search_scrip.upper())]
        else:
            filtered_data = data  # Show all if no specific scrip is requested

        print(f"\n✅ Found {len(filtered_data)} active scrips for {exchange_name} ({exchange_code.upper()})")

        # Print first 5 matching scrips
        for scrip in filtered_data[:]:  
            expiry_date = scrip.get("expiry", "N/A")  # Expiry for futures/options
            print(f"Scrip: {scrip['tradingSymbol']}, Scrip Code: {scrip['scripCode']}, Expiry: {expiry_date}")

        return filtered_data

    else:
        print(f"❌ Error fetching scrips for {exchange_code}: {response.status_code} - {response.text}")
        return []

# 🔥 Example Usage
exchange_code = input("Enter Exchange Code (NC, BC, NF, MX, RN): ").strip().upper()
search_scrip = input("Enter Scrip Name (or press Enter to show all): ").strip().upper()

fetch_scrips_by_exchange(exchange_code, search_scrip)
# Out:
# ✅ Found 2337 active scrips for NSE F&O (NF)
# Scrip: BANKNIFTY, Scrip Code: 35006, Expiry: 27/02/2025
# Scrip: BANKNIFTY, Scrip Code: 35007, Expiry: 27/02/2025
# Scrip: BANKNIFTY, Scrip Code: 35009, Expiry: 27/03/2025
# Scrip: BANKNIFTY, Scrip Code: 35010, Expiry: 27/03/2025
# Scrip: BANKNIFTY, Scrip Code: 35011, Expiry: 24/04/2025
# Scrip: BANKNIFTY, Scrip Code: 35012, Expiry: 24/04/2025
# Scrip: BANKNIFTY, Scrip Code: 35020, Expiry: 24/04/2025
# Scrip: BANKNIFTY, Scrip Code: 35021, Expiry: 24/04/2025
# Scrip: BANKNIFTY, Scrip Code: 35026, Expiry: 27/03/2025
# Scrip: BANKNIFTY, Scrip Code: 35028, Expiry: 27/03/2025
# Scrip: BANKNIFTY, Scrip Code: 35029, Expiry: 27/03/2025
# Scrip: BANKNIFTY, Scrip Code: 35030, Expiry: 27/03/2025
# Scrip: BANKNIFTY, Scrip Code: 35036, Expiry: 27/02/2025
# Scrip: BANKNIFTY, Scrip Code: 35037, Expiry: 27/02/2025
# Scrip: BANKNIFTY, Scrip Code: 35040, Expiry: 27/02/2025
# Scrip: BANKNIFTY, Scrip Code: 35041, Expiry: 27/02/2025
# ...

# %%
import sys
sys.path.append(r"C:\Users\user\Downloads\shareconnectpython-main\shareconnectpython-main\SharekhanApi")

from sharekhanWebsocket import SharekhanWebSocket  # Now it should work!

# %%
access_token = "eyJ0eXAiOiJzZWMiLCJhbGciOiJIUzI1NiJ9..KUjRlHJrtJ7xK0HJ8BTWf5JEyjww1dRhH4aZ55TtDEM"
params = {
    "access_token":access_token
}

# print(params)

# Initialize WebSocket Connection
sws = SharekhanWebSocket(access_token)

# WebSocket Subscription Request for Live Stock Price
token_list = {
    "action": "subscribe",
    "key": ["feed"],  # Correct key for Last Traded Price (LTP)
    "value": [""]  # Example for Reliance (Change this to the valid scrip code you want to track)
}
feed = {
    "action": "feed",
    "key":['ltp'],
    "value":["NF35006"]
}


# Define WebSocket Event Handlers
def on_data(wsapp, message):
    print("Raw WebSocket Data:", message)  # Debugging: Show raw data
    try:
        data = json.loads(message)  # Convert string to JSON (Python dictionary)

        # Extract the relevant data from the response
        if "data" in data and isinstance(data["data"], list) and len(data["data"]) > 0:
            scrip_data = data["data"][0]  # Get first item from the list

            # Select only important fields
            filtered_data = {
                "exchangeCode": scrip_data.get("exchangeCode", ""),
                "scripCode": scrip_data.get("scripCode", ""),
                "lastTradePrice": scrip_data.get("ltp", 0),
                "lastTradeTime": scrip_data.get("ltt", ""),
                "bidPrice": scrip_data.get("bidPrice", 0),
                "bidQty": scrip_data.get("bidQty", 0),
                "offerPrice": scrip_data.get("offPrice", 0),
                "offerQty": scrip_data.get("offQty", 0),
                "openPrice": scrip_data.get("open", 0),
                "closePrice": scrip_data.get("close", 0),
                "highPrice": scrip_data.get("high", 0),
                "lowPrice": scrip_data.get("low", 0),
                "changePercentage": scrip_data.get("perChange", 0),
                "spotPrice": scrip_data.get("spotPrice", 0),
                "oiChange": scrip_data.get("oiChange", 0),
                "currentOI": scrip_data.get("currentOI", 0),
            }

            # Print the formatted JSON output
            print(json.dumps(filtered_data, indent=4))

    except json.JSONDecodeError:
        print("Error decoding JSON")

def on_open(wsapp):
    print("WebSocket Connected")
    sws.subscribe(token_list)  # Subscribe to stock price updates
    sws.fetchData(feed)
    


def on_error(wsapp, error):
    print("WebSocket Error:", error)

# Fix: Correct on_close method signature (expecting only one argument)
def on_close(wsapp):
    print("WebSocket Connection Closed")


# Assign WebSocket Callbacks
sws.on_open = on_open
sws.on_data = on_data
sws.on_error = on_error
sws.on_close = on_close

# Start WebSocket Connection
sws.connect()
# Out:
# wss://stream.sharekhan.com/skstream/api/stream?ACCESS_TOKEN=eyJ0eXAiOiJzZWMiLCJhbGciOiJIUzI1NiJ9..KUjRlHJrtJ7xK0HJ8BTWf5JEyjww1dRhH4aZ55TtDEM
# WebSocket Connected
# Raw WebSocket Data: {"status":100,"message":"connect","timestamp":"2025-02-24T16:39:14+05:30","data":"Connected 64fbd66d-84b9-1a47-58de-1882db0b3190"}
# Raw WebSocket Data: {"status":100,"message":"subscribe","timestamp":"2025-02-24T16:39:15+05:30","data":"success FEED"}
# ...

# %% [markdown]
# Placing Order

# %%
orderparams={
 "customerId": "3975103",
 "scripCode": 2885,
 "tradingSymbol": "RELIANCE",
 "exchange": "NC",
  "transactionType": "B",
  "quantity": 1,
  "disclosedQty": 0,
  "price": "1109.7",
  "triggerPrice": "0",
   "rmsCode": "ANY",
   "afterHour": "N",
   "orderType": "NORMAL",
   "channelUser": "3975103",
   "validity": "GFD",
   "requestType": "NEW",
   "productType": "INVESTMENT",

   }
order=sharekhan.placeOrder(orderparams)
print("PlaceOrder: {}".format(order))
# Out:
# PlaceOrder: {'status': 200, 'message': 'order', 'timestamp': '2025-02-21T14:38:14+05:30', 'data': {'serverTime': '21/02/2025 14:38:12', 'orderId': '127126732', 'errormsg': '', 'rmscode': 'SKNSE4'}}

# %% [markdown]
# Modify Order

# %%
orderparams={
 "orderId":"126863890",
    "customerId": "3975103",
    "scripCode": 2885,
    "tradingSymbol": "RELIANCE",
    "exchange": "NC",
    "transactionType": "B",
    "quantity": 2,
    "disclosedQty": 0,
    "price": "81.1050",
    "triggerPrice": "0",
    "rmsCode": "SKNSE4",
    "afterHour": "N",
    "orderType": "NORMAL",
    "channelUser": "3975103",
    "validity": "GFD",
    "requestType": "MODIFY",
    "productType": "INVESTMENT",
    # "instrumentType": "FUTCUR",
    # "strikePrice": -1,
    # "expiry": "31/03/2023",
    # "optionType": "XX"
    }
order=sharekhan.modifyOrder(orderparams)
print("ModifyOrder: {}".format(order))
# Out:
# ModifyOrder: {'status': 400, 'message': 'Only Pending, Partially Executed, Triggered and After Hour Orders can be Modified/Cancelled.', 'errorType': 'input_error'}
